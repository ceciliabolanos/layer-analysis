# %% [markdown]
# # Load and plot results

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import json
from pathlib import Path

file_path = Path('cka_bert-base-uncased_bert-base-uncased.json')

with file_path.open('r', encoding='utf-8') as file:
    bert = json.load(file)

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(bert, fmt=".1f", cmap='viridis', cbar_kws={'label': 'CKA (Linear)'})
plt.xlabel(f"Capas de bert-base-uncased")
plt.ylabel(f"Capas de bert-base-uncased")
plt.ylim(0, len(bert))
plt.xticks(ticks=[i + 0.5 for i in range(len(bert))], labels=range(1, len(bert) + 1))
plt.yticks(ticks=[i + 0.5 for i in range(len(bert))], labels=range(1, len(bert) + 1))
plt.show()

# %%
plt.figure(figsize=(10, 8))

x = range(1, len(bert[0]) + 1) 
for i, row in enumerate(bert):
    plt.plot(x, row, label=f'Capa {i + 1}')  # Plot each row with a label

plt.xlabel("Capas bert-base-uncased")
plt.ylabel("CKA (Linear)")
plt.title("CKA (Linear) para cada Capa de bert-base-uncased")
plt.legend(title="Capa")  # Add a legend with a title
plt.grid(True)  # Optionally add a grid for better readability
plt.xticks(range(1,13))
plt.show()

# %%
file_path = Path('cka_wav2vec2_wav2vec2.json')

with file_path.open('r', encoding='utf-8') as file:
    w2v = json.load(file)

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(w2v, fmt=".1f", cmap='viridis', cbar_kws={'label': 'CKA (Linear)'})
plt.xlabel(f"Capas de Wav2Vec 2.0")
plt.ylabel(f"Capas de Wav2Vec 2.0")
plt.ylim(0, len(w2v))
plt.xticks(ticks=[i + 0.5 for i in range(len(w2v))], labels=range(1, len(w2v) + 1))
plt.yticks(ticks=[i + 0.5 for i in range(len(w2v))], labels=range(1, len(w2v) + 1))
plt.show()

# %%
plt.figure(figsize=(10, 8))

x = range(1, len(w2v[0]) + 1)
for i, row in enumerate(w2v):
    plt.plot(x, row, label=f'Capa {i + 1}')  # Dibujar cada fila con una etiqueta
    plt.scatter(i + 1, row[i], color='black')  # Marca en la diagonal (identidad)
    plt.scatter(7, row[6], color='red')  # Marca cuando x = 7

plt.xlabel("Capas de Wav2Vec 2.0")
plt.ylabel("CKA (Linear)")
plt.title("CKA (Linear) para cada capa de Wav2Vec 2.0 contra las demás capas")
plt.legend(title="Capa")  # Añadir una leyenda con título
plt.grid(True)  # Opcionalmente añadir una cuadrícula para mejor legibilidad
plt.xticks(range(1, 13))
plt.show()

# %%
plt.figure(figsize=(10, 8))

x = range(1, len(w2v[0]) + 1) 
for i, row in enumerate(w2v):
    plt.plot(x, row, label=f'Capa {i + 1}')  # Plot each row with a label

plt.xlabel("Capas de Wav2Vec 2.0")
plt.ylabel("CKA (Linear)")
plt.title("CKA (Linear) para cada capa de Wav2Vec 2.0 contra las demás capas")
plt.legend(title="Capa")  # Add a legend with a title
plt.grid(True)  # Optionally add a grid for better readability
plt.xticks(range(1,13))
plt.show()

# %%
file_path = Path('cka_BEATs_iter3_BEATs_iter3.json')

with file_path.open('r', encoding='utf-8') as file:
    beats = json.load(file)

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(beats, fmt=".1f", cmap='viridis', cbar_kws={'label': 'CKA (Linear)'})
plt.xlabel(f"Capas de BEATs_iter3")
plt.ylabel(f"Capas de BEATs_iter3")
plt.ylim(0, len(beats))
plt.xticks(ticks=[i + 0.5 for i in range(len(beats))], labels=range(1, len(beats) + 1))
plt.yticks(ticks=[i + 0.5 for i in range(len(beats))], labels=range(1, len(beats) + 1))
plt.show()

# %%
plt.figure(figsize=(10, 8))

x = range(1, len(bert[0]) + 1) 
for i, row in enumerate(bert):
    plt.plot(x, row, label=f'Capa {i + 1}')  # Plot each row with a label

plt.xlabel("Capas bert-base-uncased")
plt.ylabel("CKA (Linear)")
plt.title("CKA (Linear) para cada Capa de bert-base-uncased")
plt.legend(title="Capa")  # Add a legend with a title
plt.grid(True)  # Optionally add a grid for better readability
plt.xticks(range(1,13))
plt.show()

# %%
plt.figure(figsize=(10, 8))

x = range(1, len(bert[0]) + 1) 
for i, row in enumerate(bert):
    plt.plot(x, row, label=f'Capa {i + 1}')  # Plot each row with a label

plt.xlabel("Capas bert-base-uncased")
plt.ylabel("CKA (Linear)")
plt.title("CKA (Linear) para cada capa de bert-base-uncased")
plt.legend(title="Capa")  # Add a legend with a title
plt.grid(True)  # Optionally add a grid for better readability
plt.xticks(range(1,13))
plt.show()

# %%
plt.figure(figsize=(10, 8))

x = range(1, len(beats[0]) + 1) 
for i, row in enumerate(beats):
    plt.plot(x, row, label=f'Capa {i + 1}')  # Plot each row with a label

plt.xlabel("Capas beats")
plt.ylabel("CKA (Linear)")
plt.title("CKA (Linear) para cada capa de BEATs_iter3")
plt.legend(title="Capa")  # Add a legend with a title
plt.grid(True)  # Optionally add a grid for better readability
plt.xticks(range(1,13))
plt.show()

# %%
file_path = Path('cka_encodecmae_base_encodecmae_base.json')

with file_path.open('r', encoding='utf-8') as file:
    encodecmae = json.load(file)

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(encodecmae, fmt=".1f", cmap='viridis', cbar_kws={'label': 'CKA (Linear)'})
plt.xlabel(f"Capas de EncodecMAE_base")
plt.ylabel(f"Capas de EncodecMAE_base")
plt.ylim(0, len(encodecmae))
plt.xticks(ticks=[i + 0.5 for i in range(len(encodecmae))], labels=range(1, len(encodecmae) + 1))
plt.yticks(ticks=[i + 0.5 for i in range(len(encodecmae))], labels=range(1, len(encodecmae) + 1))
plt.show()

# %%
import matplotlib.pyplot as plt

# Asumiendo que encodecmae es una lista de listas o un array 2D con los datos

plt.figure(figsize=(10, 8))

x = range(1, len(encodecmae[0]) + 1) 
colors = ['red', 'red', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'green']  # Especifica los colores

for i, row in enumerate(encodecmae):
    plt.plot(x, row, label=f'Capa {i + 1}', color=colors[i])  # Asigna el color específico a cada capa

plt.xlabel("Capas de EncodecMAE_base")
plt.ylabel("CKA (Linear)")
plt.title("CKA (Linear) para cada Capa de EncodecMAE_base")
plt.legend(title="Capa")  # Añade una leyenda con un título
plt.grid(True)  # Opcionalmente añade una cuadrícula para mejor legibilidad
plt.xticks(range(1, 11))
plt.show()

# %%
data1 = bert  
data2 = w2v 
data3 = beats  
data4 = encodecmae
fig, axs = plt.subplots(2, 2, figsize=(16, 12))

# Gráfico 1
sns.heatmap(data1, fmt=".1f", cmap='viridis', cbar_kws={'label': 'CKA (Linear)'}, ax=axs[0, 0])
axs[0, 0].set_ylim(0, len(data1))
axs[0, 0].set_title('bert-base-uncased')
axs[0, 0].set_ylabel('Capas')
axs[0, 0].set_xticks([i + 0.5 for i in range(len(data1))])
axs[0, 0].set_xticklabels(range(1, len(data1) + 1))
axs[0, 0].set_yticks([i + 0.5 for i in range(len(data1))])
axs[0, 0].set_yticklabels(range(1, len(data1) + 1))

# Gráfico 2
sns.heatmap(data2, fmt=".1f", cmap='viridis', cbar_kws={'label': 'CKA (Linear)'}, ax=axs[0, 1])
axs[0, 1].set_ylim(0, len(data2))
axs[0, 1].set_title('Wav2Vec 2.0')
axs[0, 1].set_xticks([i + 0.5 for i in range(len(data2))])
axs[0, 1].set_xticklabels(range(1, len(data2) + 1))
axs[0, 1].set_yticks([i + 0.5 for i in range(len(data2))])
axs[0, 1].set_yticklabels(range(1, len(data2) + 1))

# Gráfico 3
sns.heatmap(data3, fmt=".1f", cmap='viridis', cbar_kws={'label': 'CKA (Linear)'}, ax=axs[1, 0])
axs[1, 0].set_ylim(0, len(data3))
axs[1, 0].set_title('BEATs_iter3')
axs[1, 0].set_xlabel('Capas')
axs[1, 0].set_ylabel('Capas')
axs[1, 0].set_xticks([i + 0.5 for i in range(len(data3))])
axs[1, 0].set_xticklabels(range(1, len(data3) + 1))
axs[1, 0].set_yticks([i + 0.5 for i in range(len(data3))])
axs[1, 0].set_yticklabels(range(1, len(data3) + 1))

# Gráfico 4
sns.heatmap(data4, fmt=".1f", cmap='viridis', cbar_kws={'label': 'CKA (Linear)'}, ax=axs[1, 1])
axs[1, 1].set_ylim(0, len(data4))
axs[1, 1].set_title('EncodecMAE_base')
axs[1, 1].set_xlabel('Capas')
axs[1, 1].set_xticks([i + 0.5 for i in range(len(data4))])
axs[1, 1].set_xticklabels(range(1, len(data4) + 1))
axs[1, 1].set_yticks([i + 0.5 for i in range(len(data4))])
axs[1, 1].set_yticklabels(range(1, len(data4) + 1))

plt.tight_layout()
plt.show()
